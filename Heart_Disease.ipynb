# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data_df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/heart_2020_cleaned 2.csv')

# %%
data_df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
print(f"The data consists of {data_df.shape[0]} rows and {data_df.shape[1]} columns.")
# Out:
# The data consists of 319795 rows and 18 columns.

# %%
# Missing Values Check
print("The existence of missing values in each column:")
data_df.isnull().any()
# Out:
# The existence of missing values in each column:
# HeartDisease        False
# BMI                 False
# Smoking             False
# AlcoholDrinking     False
# Stroke              False
# PhysicalHealth      False
# MentalHealth        False
# DiffWalking         False
# Sex                 False
# AgeCategory         False
# Race                False
# Diabetic            False
# PhysicalActivity    False
# GenHealth           False
# SleepTime           False
# Asthma              False
# KidneyDisease       False
# SkinCancer          False
# dtype: bool

# %%
# Info of the data
print("General information about the data:")
data_df.info()
# Out:
# General information about the data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
# Number of unique values in each column
print("The number of unique values in each column:")
data_df.nunique()
# Out:
# The number of unique values in each column:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
data_df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# <font color='red'> Hypothesis: There are outliers in the data for both maximum and minimum values.</font>

# %% [markdown]
# 1. HeartDisease: Respondents that have ever reported having
# coronary heart disease (CHD) or myocardial infarction (MI).
# BMI: Body Mass Index (BMI).
#
# 2. Smoking: Have you smoked at least 100 cigarettes in your entire life?
#
# 3. AlcoholDrinking: Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week
#
# 4. Stroke: (Ever told) (you had) a stroke?
#
# 5. PhysicalHealth: Now thinking about your physical health, which includes physical illness and injury, for how many days during the past 30 days was your physical health not good? (0-30 days).
#
# 6. MentalHealth: Thinking about your mental health, for how many days during the past 30 days was your mental health not good? (0-30 days).
#
# 7. DiffWalking: Do you have serious difficulty walking or climbing stairs?
#
# 8. Sex: Are you male or female?
#
# 9. AgeCategory: Fourteen-level age category. (then calculated the mean)
#
# 10. Race: Imputed race/ethnicity value.
#
# 11. Diabetic: (Ever told) (you had) diabetes?
#
# 12. PhysicalActivity: Adults who reported doing physical activity or exercise during the past 30 days other than their regular job.
#
# 13. GenHealth: Would you say that in general your health is...
#
# 14. SleepTime: On average, how many hours of sleep do you get in a 24-hour period?
#
# 15. Asthma: (Ever told) (you had) asthma?
#
# 16. KidneyDisease: Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?
#
# 17. SkinCancer: (Ever told) (you had) skin cancer?

# %%
data_df.AgeCategory.unique()
# Out:
# array(['55-59', '80 or older', '65-69', '75-79', '40-44', '70-74',
#        '60-64', '50-54', '45-49', '18-24', '35-39', '30-34', '25-29'],
#       dtype=object)

# %% [markdown]
# ### Categorical Features:
# HeartDisease, Smoking, AlcoholDrinking, Stroke, DiffWalking, Sex, Race, Diabetic, PhysicalActivity, GenHealth, Asthma, KidneyDisease, SkinCancer
#
# Continuous Features:
# BMI, PhysicalHealtH, MentalHealth, SleepTime

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
sns.countplot(x='HeartDisease',data=data_df,palette='coolwarm')

# %%
numeric_features=['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']
categorical_features=['HeartDisease', 'Smoking', 'AlcoholDrinking', 'Stroke', 'DiffWalking', 'Sex', 'AgeCategory',
       'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth','Asthma', 'KidneyDisease', 'SkinCancer']

# %% [markdown]
# <font color='red'>We are dealing with an unbalanced sample, where the majority of people are healthy.</font>

# %%
for column_name in numeric_features:
  plt.figure(figsize=(7, 7))
  plt.title("{column_name} Distribution".format(column_name = column_name))
  sns.histplot(data_df[column_name], stat='density',color='#E6E6FA')
  sns.kdeplot(data_df[column_name], color='black')
  plt.axvline(data_df[column_name].mean(), color='red', linestyle='--', linewidth=0.8)
  min_ylim, max_ylim = plt.ylim()
  plt.text(data_df[column_name].mean()*1.05, max_ylim*0.96, 'Mean (μ): {:.2f}'.format(data_df[column_name].mean()))
  plt.xlabel("Score")
  plt.ylabel("Density")
  plt.show()

# %% [markdown]
# <font color='red'> The BMI distribution is uniform. SleepTime distribution is multimodal. Rest are right skewed.

# %%
for feature in categorical_features:
  fig, ax1 = plt.subplots(figsize=(20,10))
  graph = sns.countplot(ax=ax1,x = feature , data = data_df,hue='HeartDisease',palette='coolwarm')
  graph.set_xticklabels(graph.get_xticklabels())
  for p in graph.patches:
    height = p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1,height ,ha="center")
# Out:
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values
# WARNING:matplotlib.text:posx and posy should be finite values

# %% [markdown]
#  ## 100% Stacked Column Chart

# %%
df=pd.crosstab(index=data_df['Smoking'],columns=data_df['HeartDisease'],normalize="index")
df
# Out:
# HeartDisease        No       Yes
# Smoking
# No            0.939666  0.060334
# Yes           0.878423  0.121577

# %%
df.plot(kind='bar',
        stacked=True,
        colormap='coolwarm',
        figsize=(10,6))
plt.legend(title="Heart Disease",loc="center")
plt.xlabel("Smoking")
plt.ylabel("Proportion")
plt.show()

# %%
smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['Smoking']=='Yes')])
num_smoke = len(data_df[data_df['Smoking']=='Yes'])
no_smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['Smoking']=='No')])
num_no_smoke = len(data_df[data_df['Smoking']=='No'])
print('Probability of Heart disease if you smoke:', smoke_and_heart_disease/num_smoke)
print("Probability of Heart disease if you don't smoke:", no_smoke_and_heart_disease/num_no_smoke)
# Out:
# Probability of Heart disease if you smoke: 0.12157715983867544
# Probability of Heart disease if you don't smoke: 0.0603341370078824

# %%
df=pd.crosstab(index=data_df['AlcoholDrinking'],columns=data_df['HeartDisease'],normalize="index")
df
# Out:
# HeartDisease           No       Yes
# AlcoholDrinking
# No               0.911978  0.088022
# Yes              0.947605  0.052395

# %%
df.plot(kind='bar',
        stacked=True,
        colormap='coolwarm',
        figsize=(10,6))
plt.legend(title="Heart Disease",loc="center")
plt.xlabel("Alcohol Drinking")
plt.ylabel("Proportion")
plt.show()

# %%
smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['AlcoholDrinking']=='Yes')])
num_smoke = len(data_df[data_df['AlcoholDrinking']=='Yes'])
no_smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['AlcoholDrinking']=='No')])
num_no_smoke = len(data_df[data_df['AlcoholDrinking']=='No'])
print('Probability of Heart disease if you drink:', smoke_and_heart_disease/num_smoke)
print("Probability of Heart disease if you don't drink:", no_smoke_and_heart_disease/num_no_smoke)
# Out:
# Probability of Heart disease if you drink: 0.05239472838315654
# Probability of Heart disease if you don't drink: 0.08802152890093887

# %%
df=pd.crosstab(index=data_df['Stroke'],columns=data_df['HeartDisease'],normalize="index")
df.plot(kind='bar',
        stacked=True,
        colormap='coolwarm',
        figsize=(10,6))
plt.legend(title="Heart Disease",loc="center")
plt.xlabel("Stroke")
plt.ylabel("Proportion")
plt.show()

# %%
smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['Stroke']=='Yes')])
num_smoke = len(data_df[data_df['Stroke']=='Yes'])
no_smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['Stroke']=='No')])
num_no_smoke = len(data_df[data_df['Stroke']=='No'])
print('Probability of Heart disease if you had a stroke:', smoke_and_heart_disease/num_smoke)
print("Probability of Heart disease if you didn't have a stroke:", no_smoke_and_heart_disease/num_no_smoke)
# Out:
# Probability of Heart disease if you had a stroke: 0.3636589609743972
# Probability of Heart disease if you didn't have a stroke: 0.07468982146454964

# %%
df=pd.crosstab(index=data_df['DiffWalking'],columns=data_df['HeartDisease'],normalize="index")
df.plot(kind='bar',
        stacked=True,
        colormap='coolwarm',
        figsize=(10,6))
plt.legend(title="Heart Disease",loc="center")
plt.xlabel("Difficulty in walking")
plt.ylabel("Proportion")
plt.show()

# %%
smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['DiffWalking']=='Yes')])
num_smoke = len(data_df[data_df['DiffWalking']=='Yes'])
no_smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['DiffWalking']=='No')])
num_no_smoke = len(data_df[data_df['DiffWalking']=='No'])
print('Probability of Heart disease if you have difficulty in walking:', smoke_and_heart_disease/num_smoke)
print("Probability of Heart disease if you do not have difficulty in walking:", no_smoke_and_heart_disease/num_no_smoke)
# Out:
# Probability of Heart disease if you have difficulty in walking: 0.22580499887412744
# Probability of Heart disease if you do not have difficulty in walking: 0.0629845489042613

# %%
df=pd.crosstab(index=data_df['Sex'],columns=data_df['HeartDisease'],normalize="index")
df.plot(kind='bar',
        stacked=True,
        colormap='coolwarm',
        figsize=(10,6))
plt.legend(title="Heart Disease",loc="center")
plt.xlabel("Sex")
plt.ylabel("Proportion")
plt.show()

# %%
df=pd.crosstab(index=data_df['AgeCategory'],columns=data_df['HeartDisease'],normalize="index")
df.plot(kind='bar',
        stacked=True,
        colormap='coolwarm',
        figsize=(10,6))
plt.legend(title="Heart Disease",loc="center")
plt.xlabel("AgeCategory")
plt.ylabel("Proportion")
plt.show()

# %%
df=pd.crosstab(index=data_df['Race'],columns=data_df['HeartDisease'],normalize="index")
df.plot(kind='bar',
        stacked=True,
        colormap='coolwarm',
        figsize=(10,6))
plt.legend(title="Heart Disease",loc="center")
plt.xlabel("Race")
plt.ylabel("Proportion")
plt.show()

# %%
smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['Sex']=='Male')])
num_smoke = len(data_df[data_df['Sex']=='Male'])
no_smoke_and_heart_disease = len(data_df[(data_df['HeartDisease']=='Yes') & (data_df['Sex']=='Female')])
num_no_smoke = len(data_df[data_df['Sex']=='Female'])
print("Probability of Heart disease if you're a male:", smoke_and_heart_disease/num_smoke)
print("Probability of Heart disease if you're a female:", no_smoke_and_heart_disease/num_no_smoke)
# Out:
# Probability of Heart disease if you're a male: 0.10618461740904007
# Probability of Heart disease if you're a female: 0.06694675367241738

# %%
correlation = data_df.corr().round(2)
plt.figure(figsize = (14,7))
sns.heatmap(correlation, annot = True, cmap = 'YlOrBr')

# %% [markdown]
# Physical health and meantal health have a fairly strong correltion.

# %%
#SQL
data_df =  data_df[data_df.columns].replace({'Yes':1, 'No':0, 'Male':1,'Female':0,'No, borderline diabetes':'0','Yes (during pregnancy)':'1' })
data_df['Diabetic'] = data_df['Diabetic'].astype(int)

# %%
correlation = data_df.corr().round(2)
plt.figure(figsize = (14,7))
sns.heatmap(correlation, annot = True, cmap = 'YlOrBr')

# %% [markdown]
# Distribution of correlation of features against heart disease

# %%
sns.set_style('white')
sns.set_palette('coolwarm')
plt.figure(figsize = (13,6))
plt.title('Distribution of correlation of features')
abs(correlation['HeartDisease']).sort_values()[:-1].plot.barh()
plt.show()

# %% [markdown]
# ##Distribution of numeric features comparing people with heart disease and without heart disease

# %%
fig, ax = plt.subplots(figsize = (13,5))
sns.kdeplot(data_df[data_df["HeartDisease"]==1]["BMI"], alpha=0.5,shade = True, color="red", label="HeartDisease", ax = ax)
sns.kdeplot(data_df[data_df["HeartDisease"]==0]["BMI"], alpha=0.5,shade = True, color="#fccc79", label="Normal", ax = ax)
plt.title('Distribution of Body Mass Index', fontsize = 18)
ax.set_xlabel("BodyMass")
ax.set_ylabel("Frequency")
ax.legend();
plt.show()

# %%
fig, ax = plt.subplots(figsize = (13,5))
sns.distplot(data_df[data_df["HeartDisease"]==1]["SleepTime"], color="red", label="HeartDisease",bins=20)
sns.distplot(data_df[data_df["HeartDisease"]==0]["SleepTime"], color="#fccc79", label="Normal",bins=20)
plt.title('Distribution of Sleep Time', fontsize = 18)
ax.set_xlabel("BodyMass")
ax.set_ylabel("Frequency")
ax.legend();
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
plt.ylim(0,30)
sns.boxplot(x='HeartDisease', y='SleepTime',data=data_df,palette='RdBu')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.ylim(0,30)
sns.boxplot(x='HeartDisease', y='PhysicalHealth',data=data_df,palette='RdBu')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.ylim(0,30)
sns.boxplot(x='HeartDisease', y='MentalHealth',data=data_df,palette='RdBu')
plt.show()

# %%
i=1
plt.figure(figsize=(15,25))
for feature in numeric_features:
    plt.subplot(6,2,i)
    sns.boxplot(y=data_df[feature], x = data_df['AlcoholDrinking'],palette='coolwarm')
    i+=1
